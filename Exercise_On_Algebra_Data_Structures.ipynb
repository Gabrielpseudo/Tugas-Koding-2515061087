# %%
import numpy as np
#Selesaikan soal berikut
vektor = np.array([[25],
                   [2],
                   [-3],
                   [-23]])

transpose_vektor = vektor.T
print(transpose_vektor)
# Out:
# [[ 25   2  -3 -23]]
