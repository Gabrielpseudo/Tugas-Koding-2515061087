# %%
import numpy as np
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[25, 15, 6], [10, 8,7]])
X
# Out:
# array([[25, 15,  6],
#        [10,  8,  7]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([25, 10])

# %%
#Tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([10,  8,  7])

# %%
# ulangi soal nomor 1 menggunakan PyTorch
import torch

x_pt = torch.tensor([[25, 15, 6], [10, 8,7]])
x_pt
# Out:
# tensor([[25, 15,  6],
#         [10,  8,  7]])

# %%
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
x_pt[:,0]
# Out:
# tensor([25, 10])

# %%
x_pt[1,:]
# Out:
# tensor([10,  8,  7])

# %%
#Ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

x_tf = tf.Variable([[25, 15, 6], [10, 8,7]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[25, 15,  6],
#        [10,  8,  7]], dtype=int32)>

# %%
x_tf.shape
# Out:
# TensorShape([2, 3])

# %%
x_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([25, 10], dtype=int32)>

# %%
x_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([10,  8,  7], dtype=int32)>
