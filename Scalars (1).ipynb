# %%
#Membuat variabel skalar x dan menyimpan nilai skalar
x = 1087
x
# Out:
# 1087

# %%
#Menampilkan tipe data x
type(x)
# Out:
# int

# %%
#Membuat variabel skalar y dan menyimpan nilai skalar
y = 1087
y
# Out:
# 1087

# %%
#Menampilkan tipe data y
type(y)
# Out:
# int

# %%
#Menjumlahkan x dan y
py_sum = x + y
py_sum
# Out:
# 2174

# %%
#Membuat nilai x_float dan menyimpan nilai desimal dan menjumlahkan x_float dengan y
x_float = 10.87
py_sum = x_float + y
py_sum
# Out:
# 1097.87

# %%
#Menampilkan tipe data x_float
type(x_float)
# Out:
# float

# %%
import tensorflow as tf

# %%
#Lakukan tahapan pada soal 1 dengan menggunakan tensorflow
x_tf = tf.Variable(87, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=87>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(87, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=87>

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=174>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=174>

# %%
tf_sum.numpy()
# Out:
# np.int16(174)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(8.7, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=8.703125>

# %%
#Lakukan tahapan pada soal 1 dengan menggunakan pytorch
import torch

# %%
x_pt = torch.tensor(87, dtype=torch.int16)
x_pt
# Out:
# tensor(87, dtype=torch.int16)

# %%
type(x_pt)
# Out:
# torch.Tensor

# %%
y_pt = torch.tensor(10, dtype=torch.int16)
y_pt
# Out:
# tensor(10, dtype=torch.int16)

# %%
x_pt + y_pt
# Out:
# tensor(97, dtype=torch.int16)

# %%
x_float_tr = torch.tensor(8.7, dtype=torch.float16)
x_float_tr
# Out:
# tensor(8.7031, dtype=torch.float16)

# %%
x_float_tr + y_pt
# Out:
# tensor(18.7031, dtype=torch.float16)

# %%
type(x_float_tr)
# Out:
# torch.Tensor
