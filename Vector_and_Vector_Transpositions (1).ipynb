# %%
import numpy as np

# %%
#Buat vector x dengan ukuran 3x1
x = np.array([[15], [10], [87]])
x
# Out:
# array([[15],
#        [10],
#        [87]])

# %%
#Hitung panjang Vector X
len(x)
# Out:
# 3

# %%
#Menampilkan ukuran Vector X
x.shape
# Out:
# (3, 1)

# %%
#Menampilkan tipe data Vector X
type(x)
# Out:
# numpy.ndarray

# %%
#Akses elemen pertama dari Vector X
x[0]
# Out:
# array([15])

# %%
#Menampilkan tipe data pertama dari Vector X
type(x[0])
# Out:
# numpy.ndarray

# %%
#Lakukan transpose pada vector X dan simpan pada vector x_t
x_t = x.T
x_t
# Out:
# array([[15, 10, 87]])

# %%
#Menampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (1, 3)

# %%
#Lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[15], [10], [87]])
y
# Out:
# array([[15],
#        [10],
#        [87]])

# %%
y_t = y.T
y_t
# Out:
# array([[15, 10, 87]])

# %%
#Menampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (1, 3)

# %%
#Tensorflow dan PyTorch
import tensorflow as tf
import torch

# %%
#Tensorflow
x_tf = tf.Variable([[6],[10],[87]])
x_tf
tf.transpose(x_tf)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[ 6, 10, 87]], dtype=int32)>

# %%
tf.transpose(x_tf).shape
# Out:
# TensorShape([1, 3])

# %%
y_tf = tf.Variable([[6],[10],[87]])
y_tf
tf.transpose(x_tf)
# Out:
# <tf.Tensor: shape=(1, 3), dtype=int32, numpy=array([[ 6, 10, 87]], dtype=int32)>

# %%
tf.transpose(x_tf).shape
# Out:
# TensorShape([1, 3])

# %%
#PyTorch
x_pt = torch.tensor([[6], [10], [87]])
x_pt_t = x_pt.T
x_pt_t
# Out:
# tensor([[ 6, 10, 87]])

# %%
x_pt_t.shape
# Out:
# torch.Size([1, 3])

# %%
y_pt = torch.tensor([[6], [10], [87]])
y_pt_t = x_pt.T
y_pt_t
# Out:
# tensor([[ 6, 10, 87]])

# %%
x_pt_t.shape
# Out:
# torch.Size([1, 3])
